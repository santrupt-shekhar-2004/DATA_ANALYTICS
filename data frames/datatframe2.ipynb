# %%
import pandas as pd

# %%
stats = pd.read_csv('/Users/santruptshekhar/Desktop/workspace/data-analytics/gfg-practice/DemographicData.csv')

# %%
stats
# Out:
#              Country Name Country Code  Birth rate  Internet users  \
# 0                   Aruba          ABW      10.244            78.9
# 1             Afghanistan          AFG      35.253             5.9
# 2                  Angola          AGO      45.985            19.1
# 3                 Albania          ALB      12.877            57.2
# 4    United Arab Emirates          ARE      11.044            88.0
# ..                    ...          ...         ...             ...
# 190           Yemen, Rep.          YEM      32.947            20.0
# 191          South Africa          ZAF      20.850            46.5
# 192      Congo, Dem. Rep.          COD      42.394             2.2
# 193                Zambia          ZMB      40.471            15.4
# 194              Zimbabwe          ZWE      35.715            18.5
#
#             Income Group
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ...

# %%
stats.columns=[['a','b','birthrate','internetusers','e']]

# %%
stats
# Out:
#                         a    b birthrate internetusers                    e
# 0                   Aruba  ABW    10.244          78.9          High income
# 1             Afghanistan  AFG    35.253           5.9           Low income
# 2                  Angola  AGO    45.985          19.1  Upper middle income
# 3                 Albania  ALB    12.877          57.2  Upper middle income
# 4    United Arab Emirates  ARE    11.044          88.0          High income
# ..                    ...  ...       ...           ...                  ...
# 190           Yemen, Rep.  YEM    32.947          20.0  Lower middle income
# 191          South Africa  ZAF    20.850          46.5  Upper middle income
# 192      Congo, Dem. Rep.  COD    42.394           2.2           Low income
# 193                Zambia  ZMB    40.471          15.4  Lower middle income
# 194              Zimbabwe  ZWE    35.715          18.5           Low income
#
# [195 rows x 5 columns]

# %%
result = stats.birthrate * stats.internetusers #BASIC ARTHEMATIC OPERATIONS ARE PERFORMED LIKE THIS, ITS NOT WORKING RN BUT THIS IS THE WAY

# %%
result
# Out:
#     birthrate internetusers
# 0         NaN           NaN
# 1         NaN           NaN
# 2         NaN           NaN
# 3         NaN           NaN
# 4         NaN           NaN
# ..        ...           ...
# 190       NaN           NaN
# 191       NaN           NaN
# 192       NaN           NaN
# 193       NaN           NaN
# 194       NaN           NaN
#
# [195 rows x 2 columns]

# %%
stats['product']= stats.birthrate * stats.internetusers  #THIS IS TO ADD A COLUMN AND WE HAVE TO HAVE SAME NUMBER OF VALUES IN THAT COLUMN AS THE ROWS
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 stats['product']= stats.birthrate * stats.internetusers
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3970, in DataFrame.__setitem__(self, key, value)
#    3968     self._setitem_array(key, value)
#    3969 elif isinstance(value, DataFrame):
# -> 3970     self._set_item_frame_value(key, value)
#    3971 elif (
#    3972     is_list_like(value)
#    3973     and not self.columns.is_unique
#    3974     and 1 < len(self.columns.get_indexer_for([key])) == len(value)
#    3975 ):
#    3976     # Column to set is duplicated
#    3977     self._setitem_array([key], value)
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:4125, in DataFrame._set_item_frame_value(self, key, value)
#    4122     return
#    4124 if len(value.columns) != 1:
# ...

# %%
stats.drop('a',1) # to remove a column. by default drop delets a row so inorder to delete a colum we write 1 which represents column and 0 which represents row
# its basically the axis value we are changing. You can see that by shift tab
# Out:
# /var/folders/_d/g5lby8x90cb5pw610257gcc40000gp/T/ipykernel_78688/886741412.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   stats.drop('a',1)
# /var/folders/_d/g5lby8x90cb5pw610257gcc40000gp/T/ipykernel_78688/886741412.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   stats.drop('a',1)
#        b birthrate internetusers                    e
# 0    ABW    10.244          78.9          High income
# 1    AFG    35.253           5.9           Low income
# 2    AGO    45.985          19.1  Upper middle income
# 3    ALB    12.877          57.2  Upper middle income
# 4    ARE    11.044          88.0          High income
# ..   ...       ...           ...                  ...
# 190  YEM    32.947          20.0  Lower middle income
# 191  ZAF    20.850          46.5  Upper middle income
# ...

# %%
stats.birthrate > 2
# Out:
#     birthrate
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# ..        ...
# 190      True
# 191      True
# 192      True
# 193      True
# 194      True
#
# [195 rows x 1 columns]
